baseline['PR']['GAT'] =  ['0.35670560598373413', '0.49580562114715576', '0.5539121627807617', '0.6226702928543091', '0.6561993956565857', '0.6693655848503113', '0.6766725778579712', '0.6874904632568359', '0.689690113067627', '0.6992617845535278', '0.7035015821456909', '0.7067983150482178', '0.7095474004745483', '0.7135910391807556', '0.7201375961303711', '0.7203693985939026', '0.7227764129638672', '0.7232264876365662', '0.7290517687797546', '0.7299500703811646', '0.7309003472328186', '0.7302799224853516', '0.7372534275054932', '0.7405502200126648', '0.7375516891479492', '0.7408836483955383', '0.7381169199943542', '0.7404100894927979', '0.7407246232032776', '0.7412609457969666']

# %%
fig, axs = plt.subplots(2, 2,figsize=(8, 4))

datasets = ["PR", "PA"]
models = ["SAGE", "GAT"]

print(axs)
v = [i for i in range(10)]

for i,model in enumerate(models):
    for j, dataset in enumerate(datasets):
        curve_naive = baseline[dataset][model][:30]
        curve_naive = [float(i) for i in curve_naive]
        curve_groot = groot[dataset][model][:30]
        curve_groot = [float(i) for i in curve_groot]
        assert(len(curve_groot) == 30)
        assert(len(curve_naive) == 30)
        epoch = [i for i in range(30)]
        #if i==0 and j ==0:
        #axs[2*i+j].plot(epoch, curve_naive , 'r*', label = 'Naive')
        #axs[2*i+j].plot(epoch, curve_groot, 'b-', label = 'GRoot')
        #else:
        #    axs[2*i+j].plot(epoch, curve_naive , 'r*')
        #    axs[2*i+j].plot(epoch, curve_groot, 'b-')
#         print(axs[2*i+j])
        axs[i,j].plot(epoch, curve_naive , '*', color =pallete[0],label = 'DGL')
        axs[i,j].plot(epoch, curve_groot, '-', color =pallete[3],label = 'GSplit')
#         if i==0 and j==0:
            
#         axs[i,j].legend(borderaxespad=0.)  
        axs[i,j].set_ylim(bottom=0, top=1)
#         if i == 1:
#            axs[i,j].get_xaxis().set_visible(False)
        #else:
        axs[i,j].set_xlabel(dataset)
#         if j ==  0:
#            axs[i,j].get_yaxis().set_visible(False)
        #else:
        axs[i,j].set_ylabel(model)
        abcd = ["a","b","c","d"]
#         axs[2*i+j].set_title("("+abcd[2*i+j]+") "+model+" on the "+dataset + " Dataset")
#fig.legend(bbox_to_anchor=(.5, 0), borderaxespad=0.)            
            
#         axs[i][j].spines['top'].set_color('none')
#         axs[i][j].spines['bottom'].set_color('none')
#         axs[i][j].spines['left'].set_color('none')
#         axs[i][j].spines['right'].set_color('none')
        
# ax2 = ax1.twinx()

#fig.suptitle('Test Accuracy', fontsize=16)

# ax1.plot(x, y1, 'g-')
# ax2.plot(x, y2, 'b-')

# ax1.set_xlabel('Cache Percentage')
# ax1.set_ylabel('ratio of redundant data', color='g')
# ax2.set_ylabel('ratio of data movement time', color='b')
handles, labels = axs[0][0].get_legend_handles_labels()
fig.legend(handles, labels, ncol=2, loc='center' , bbox_to_anchor= (0.5,0))
# plt.show()
# plt.legend(handles=[ red_patch, red_patch1],ncol=2, loc="lower right",bbox_to_anchor=  (1, -0.35), frameon=False)

plt.savefig('test_accuracy.pdf', bbox_inches='tight')
# Out:
# [[<AxesSubplot:> <AxesSubplot:>]
#  [<AxesSubplot:> <AxesSubplot:>]]

# %%
fig, axs = plt.subplots(1, 2,figsize=(8, 4))

datasets = ["PR","PA"]
models = ["SAGE", "GAT"]

print(axs)
v = [i for i in range(10)]

for i in range(2):
    model = models[i]
    dataset = datasets[i]
    j = i
    curve_naive = baseline[dataset][model][:30]
    curve_naive = [float(i) for i in curve_naive]
    curve_groot = groot[dataset][model][:30]
    curve_groot = [float(i) for i in curve_groot]
    assert(len(curve_groot) == 30)
    assert(len(curve_naive) == 30)
    epoch = [i for i in range(30)]
        #if i==0 and j ==0:
        #axs[2*i+j].plot(epoch, curve_naive , 'r*', label = 'Naive')
        #axs[2*i+j].plot(epoch, curve_groot, 'b-', label = 'GRoot')
        #else:
        #    axs[2*i+j].plot(epoch, curve_naive , 'r*')
        #    axs[2*i+j].plot(epoch, curve_groot, 'b-')
#         print(axs[2*i+j])
    axs[i].plot(epoch, curve_naive , '*', color =pallete[0],label = 'DGL')
    axs[i].plot(epoch, curve_groot, '-', color =pallete[3],label = 'GSplit')
#         if i==0 and j==0:
            
#         axs[i,j].legend(borderaxespad=0.)  
    axs[i].set_ylim(bottom=0, top=1)
#         if i == 1:
#            axs[i,j].get_xaxis().set_visible(False)
        #else:
    axs[i].set_xlabel(dataset)
#         if j ==  0:
#            axs[i,j].get_yaxis().set_visible(False)
        #else:
    axs[i].set_ylabel(model)
#         abcd = ["a","b","c","d"]
#         axs[2*i+j].set_title("("+abcd[2*i+j]+") "+model+" on the "+dataset + " Dataset")
#fig.legend(bbox_to_anchor=(.5, 0), borderaxespad=0.)            
            
#         axs[i][j].spines['top'].set_color('none')
#         axs[i][j].spines['bottom'].set_color('none')
#         axs[i][j].spines['left'].set_color('none')
#         axs[i][j].spines['right'].set_color('none')
        
# ax2 = ax1.twinx()

#fig.suptitle('Test Accuracy', fontsize=16)

# ax1.plot(x, y1, 'g-')
# ax2.plot(x, y2, 'b-')

# ax1.set_xlabel('Cache Percentage')
# ax1.set_ylabel('ratio of redundant data', color='g')
# ax2.set_ylabel('ratio of data movement time', color='b')
handles, labels = axs[0].get_legend_handles_labels()
fig.legend(handles, labels, ncol=2, loc='center' , bbox_to_anchor= (0.5,0))
# plt.show()
# plt.legend(handles=[ red_patch, red_patch1],ncol=2, loc="lower right",bbox_to_anchor=  (1, -0.35), frameon=False)

plt.savefig('test_accuracy.pdf', bbox_inches='tight')
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# [<AxesSubplot:> <AxesSubplot:>]
